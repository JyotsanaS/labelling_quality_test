# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# fatal: destination path 'yolov7' already exists and is not an empty directory.

# %%
# %cd yolov7/
# !git checkout 44f30af0daccb1a3baecc5d80eae22948516c579
# Out:
# /home/ubuntu/1.1Tdisk/walmart_tan/dataset_new/yolov7
# Note: switching to '44f30af0daccb1a3baecc5d80eae22948516c579'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 44f30af u7 readme

# %%
# %cd ./seg/
# Out:
# /home/ubuntu/1.1Tdisk/walmart_tan/dataset_new/yolov7/seg

# %%
# !pip install --upgrade pip
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.8 MB/s eta 0:00:0031m9.3 MB/s eta 0:00:01
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# googleapis-common-protos 1.59.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# grpcio-tools 1.60.0 requires grpcio>=1.60.0, but you have grpcio 1.53.0 which is incompatible.
# ...

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1sPYHUcIW48sJ67kh5MHOI3GfoXlYNOfJ' -O dog.jpeg

IMAGE_PATH = f"./dog.jpeg"
# Out:
# --2024-01-23 06:44:56--  https://docs.google.com/uc?export=download&id=1sPYHUcIW48sJ67kh5MHOI3GfoXlYNOfJ
# Resolving docs.google.com (docs.google.com)... 142.250.190.110, 2607:f8b0:4009:806::200e
# Connecting to docs.google.com (docs.google.com)|142.250.190.110|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1sPYHUcIW48sJ67kh5MHOI3GfoXlYNOfJ&export=download [following]
# --2024-01-23 06:44:56--  https://drive.usercontent.google.com/download?id=1sPYHUcIW48sJ67kh5MHOI3GfoXlYNOfJ&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.191.97, 2607:f8b0:4009:817::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.191.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106055 (104K) [image/jpeg]
# Saving to: ‘dog.jpeg’
#
# ...

# %%
# !python segment/predict.py --weights ./ht_segmentation_v5.pt  --source ./dog.jpeg --name coco
# Out:
# segment/predict: weights=['./ht_segmentation_v5.pt'], source=./dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=coco, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2024-1-23 Python-3.10.6 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 14960MiB)
#
# Fusing layers...
# Model summary: 325 layers, 37853264 parameters, 0 gradients, 141.9 GFLOPs
# image 1/1 /home/ubuntu/1.1Tdisk/walmart_tan/dataset_new/yolov7/seg/dog.jpeg: 640x384 2 Products, 21.4ms
# Speed: 0.6ms pre-process, 21.4ms inference, 20.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/predict-seg/coco4

# %%
RESULT_IMAGE_PATH = "./runs/predict-seg/coco2/dog.jpeg"

from IPython.display import Image, display

display(Image(filename=RESULT_IMAGE_PATH))

# %%
# !python segment/predict.py --weights './ht_segmentation_v5.pt' --source '/home/ubuntu/1.1Tdisk/walmart_tan/dataset_new/dataset_whole/training_valid_dataset/hardtail_cv_february_2023-13/train/images/'
# Out:
# segment/predict: weights=['./ht_segmentation_v5.pt'], source=/home/ubuntu/1.1Tdisk/walmart_tan/dataset_new/dataset_whole/training_valid_dataset/hardtail_cv_february_2023-13/train/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2024-1-23 Python-3.10.6 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 14960MiB)
#
# Fusing layers...
# Model summary: 325 layers, 37853264 parameters, 0 gradients, 141.9 GFLOPs
# image 1/376 /home/ubuntu/1.1Tdisk/walmart_tan/dataset_new/dataset_whole/training_valid_dataset/hardtail_cv_february_2023-13/train/images/0_jpg.rf.c993618a229fb7d2223b835535d2c772.jpg: 384x640 16 Products, 21.9ms
# ...

# %%
RESULT_IMAGE_PATH = "./runs/predict-seg/exp/2023-01-30_ht_video2_mp4-44_jpg.rf.378ce1f6d54d6f6d27b41cb34c56916e.jpg"

from IPython.display import Image, display

display(Image(filename=RESULT_IMAGE_PATH))
